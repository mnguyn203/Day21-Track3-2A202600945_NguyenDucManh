# %% [markdown]
# # Lab 21 — LoRA / QLoRA Fine-tuning · **T4 / Free Colab Edition**
#
# **AICB-P2T3 · Ngày 21 · Chương 5 — Fine-tuning & An Toàn**
#
# Mục tiêu: fine-tune **Qwen2.5-3B** với LoRA/QLoRA trên một custom Vietnamese dataset, sau đó so sánh các rank khác nhau (`r=8`, `r=16`, `r=64`).
#
# ---
#
# ## ⚙️ Profile: `T4`
#
# | Setting | Giá trị |
# |---|---|
# | Model | `unsloth/Qwen2.5-3B-bnb-4bit` |
# | Recommended GPU | T4 (16 GB) |
# | Train batch / eval batch | 1 / 1 |
# | Gradient accumulation | 8 (effective batch = 8) |
# | Eval strategy | "no" |
# | Max seq length cap | 1024 |
# | Dataset samples | 200 |
# | Estimated time | ~60 phút trên T4 |
#
# > ⚠️ **T4-specific tweaks**: dùng model 3B (thay vì 7B), tắt eval-during-training, batch size = 1, manual eval fallback. Nếu bạn có GPU lớn hơn, dùng phiên bản BigGPU.
#
# ## Lab Roadmap (≈ 2 giờ)
#
# | # | Bước | Output |
# |---|------|--------|
# | 1 | Dataset preparation (Alpaca format, p95 tokenization, 90/10 split) | `train_ds`, `eval_ds` |
# | 2 | Configure PEFT + load model 4-bit | model wrapped với LoRA |
# | 3 | Train baseline `r=16` với SFTTrainer | adapter checkpoint |
# | 4 | Rank experiment — train `r=8` và `r=64` | 2 adapter checkpoints |
# | 5 | Evaluate (perplexity + qualitative) | so sánh metrics |
# | 6 | Save + viết report | deliverable |
#
# ## Deliverable
#
# 1. **3 LoRA adapter checkpoints** (`r=8, r=16, r=64`)
# 2. **Evaluation report** chứa training time, peak VRAM, eval perplexity, 5 qualitative before/after examples, training cost, kết luận về rank trade-off

# %% [markdown]
# ## 0. Setup & Environment Check

# %%
# Verify GPU is available before installing anything
# !nvidia-smi
# Out:
# Thu Jun 25 04:05:12 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
assert torch.cuda.is_available(), "❌ GPU runtime cần được bật. Runtime > Change runtime type > GPU"
name = torch.cuda.get_device_name(0)
vram_gb = torch.cuda.get_device_properties(0).total_memory / 1e9
print(f"✓ GPU: {name}")
print(f"✓ VRAM: {vram_gb:.1f} GB")
print(f"✓ CUDA: {torch.version.cuda}")
print(f"✓ PyTorch: {torch.__version__}")

if vram_gb > 20:
    print("\n⚠️  Bạn có GPU lớn (>20GB VRAM). Nên dùng phiên bản BigGPU thay vì T4 này — sẽ nhanh hơn nhiều!")
elif 'T4' not in name:
    print(f"\n💡 Notebook này tối ưu cho T4 (16GB). GPU của bạn ({name}) có thể chạy được nhưng underutilized.")
# Out:
# ✓ GPU: Tesla T4
# ✓ VRAM: 15.6 GB
# ✓ CUDA: 12.8
# ✓ PyTorch: 2.11.0+cu128

# %%
# Install Unsloth, TRL, datasets, evaluation libs
# trl >= 0.12 — accepts processing_class (matches transformers >= 4.46)
# %%capture
# !pip install -q --upgrade pip
# !pip install -q "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install -q --no-deps "trl>=0.12,<0.16" peft accelerate bitsandbytes
# !pip install -q datasets matplotlib seaborn pandas

# %%
# Optional: mount Google Drive to save checkpoints persistently
MOUNT_DRIVE = False  # ← đổi thành True nếu muốn save vào Drive

if MOUNT_DRIVE:
    from google.colab import drive
    drive.mount('/content/drive')
    OUTPUT_DIR = '/content/drive/MyDrive/lab21_lora_t4'
else:
    OUTPUT_DIR = '/content/lab21_lora_t4'

import os
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"✓ Output dir: {OUTPUT_DIR}")
# Out:
# ✓ Output dir: /content/lab21_lora_t4

# %% [markdown]
# ## 1. Dataset Preparation
#
# Mục tiêu: chuẩn bị 100–500 examples Alpaca format. Có 2 lựa chọn:
#
# **A. Dùng dataset có sẵn** — load Vietnamese instruction dataset từ HuggingFace.
# **B. Dùng dataset của bạn** — uncomment cell B và paste data.

# %%
# ─── Option C: Legal Instruct Dataset (Bonus) ───
from datasets import load_dataset

raw = load_dataset("duyet/vietnamese-legal-instruct", split="train")
raw = raw.shuffle(seed=42).select(range(300))
print(f"✓ Loaded {len(raw)} samples")
print(f"✓ Columns: {raw.column_names}")
print("\n--- Sample 0 ---")
print(raw[0])
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:134: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# README.md:   0%|          | 0.00/6.39k [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# data/train-00000-of-00003.parquet:   0%|          | 0.00/469M [00:00<?, ?B/s]
# data/train-00001-of-00003.parquet:   0%|          | 0.00/471M [00:00<?, ?B/s]
# data/train-00002-of-00003.parquet:   0%|          | 0.00/469M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/74.3M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/222172 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/11694 [00:00<?, ? examples/s]
# ✓ Loaded 300 samples
# ✓ Columns: ['qa_type', 'conversations', 'source_id', 'document_type']
#
# --- Sample 0 ---
# {'qa_type': 'qa_practical', 'conversations': [{'content': 'Bạn là luật sư tư vấn pháp luật Việt Nam. Trả lời chính xác, trích dẫn điều khoản cụ thể, tư vấn thực tiễn. Tiếng Việt.', 'role': 'system'}, {'content': 'Phân tích thực tiễn:\n\nQUYẾT ĐỊNH\n\nCỦA NGÂN HÀNG NHÀ NƯỚC\n\nSỐ 21/2008/QĐ-NHNN NGÀY 11 THÁNG 7 NĂM 2008\n\nBan hành quy chế đại lý đổi ngoại tệ\n\n_____________________\n\nTHỐNG ĐỐC NGÂN HÀNG NHÀ NƯỚC\n\nCăn cứ Luật Ngân hàng Nhà nước Việt Nam năm 1997 và Luật sửa đổi, bổ sung một số điều của Luật Ngân hàng Nhà nước Việt Nam năm 2003;\n\nCăn cứ Pháp lệnh Ngoại hối năm 2005;\n\nCăn cứ Nghị định số 160/2006/NĐ-CP ngày 28/12/2006 của Chính phủ quy định chi tiết thi hành Pháp lệnh ngoại hối;\n\nCăn cứ Nghị định số 52/2003/NĐ-CP ngày 19/5/2003 của Chính phủ quy định về chức năng, nhiệm vụ, quyền hạn và cơ cấu tổ chức của Ngân hàng Nhà nước Việt Nam;\n\nTheo đề nghị của Vụ trưởng Vụ Quản lý Ngoại hối,\n\nQUYẾT ĐỊNH:\n\nĐiều\n\n1.\n\nBan hành kèm theo Quyết định này Quy chế Đại lý đổi ngoại tệ.\n\nĐiều\n\n2.\n\nQuyết định này có hiệu lực sau 15 ngày kể từ ngày đăng công báo và thay thế Quyết định số 1216/2003/QĐ-NHNN ngày 09/10/2003 của Thống đốc Ngân hàng Nhà nước về việc ban hành Quy chế hoạt động của bàn đổi ngoại tệ.\n\nĐiều\n\n3.\n\nChánh Văn phòng, Vụ trưởng Vụ Quản lý Ngoại hối, Thủ trưởng các đơn vị thuộc Ngân hàng Nhà nước có liên quan, Giám đốc Ngân hàng Nhà nước Chi nhánh tỉnh, thành phố trực thuộc Trung ương, Tổng giám đốc (Giám đốc) các tổ chức tín dụng được phép cung ứng dịch vụ ngoại hối, các tổ chức làm Đại lý đổi ngoại tệ và các cá nhân có liên quan chịu trách nhiệm thi hành Quyết định này.\n\nQUY CHẾ\n\nĐẠI LÝ ĐỔI NGOẠI TỆ\n\n(Ban hành kèm theo Quyết định số 21/2008/QĐ-NHNN ngày 11 tháng 7 năm 2008 của Thống đốc Ngân hàng Nhà nước)\n\nChương 1.\n\nQUY ĐỊNH CHUNG\n\nĐiều 1. Phạm vi điều chỉnh.\n\n1. Quy chế này điều chỉnh hoạt động đổi ngoại tệ của tổ chức làm Đại lý đổi ngoại tệ cho Tổ chức tín dụng được phép cung ứng dịch vụ ngoại hối (dưới đây gọi là Tổ chức tín dụng được phép) trên lãnh thổ nước Cộng hòa xã hội chủ nghĩa Việt Nam.\n\n2. Hoạt động đổi ngoại tệ của các Tổ chức tín dụng được phép thực hiện theo quy định của Tổng Giám đốc (Giám đốc) Tổ chức tín dụng được phép phù hợp với quy định về mạng lưới hoạt động của Tổ chức tín dụng.\n\n3. Hoạt động đổi đồng tiền của nước có chung biên giới với Việt Nam thực hiện theo quy định tại các văn bản quy phạm pháp luật khác và không chịu sự điều chỉnh của Quy chế này.\n\nĐiều 2. Đối tượng làm Đại lý đổi ngoại tệ.\n\nCác tổ chức kinh tế thuộc mọi thành phần (sau đây gọi là tổ chức) có đủ các điều kiện quy định tại Điều 5 Quy chế này được làm Đại lý đổi ngoại tệ cho các Tổ chức tín dụng được phép trên cơ sở hợp đồng Đại lý đổi ngoại tệ giữa Tổ chức tín dụng và tổ chức.\n\nĐại lý đổi ngoại tệ chỉ được hoạt động sau khi được Ngân hàng Nhà nước Chi nhánh tỉnh, thành phố trực thuộc Trung ương (dưới đây gọi là Ngân hàng Nhà nước Chi nhánh tỉnh, thành phố) trên địa bàn cấp Giấy chứng nhận đăng ký Đại lý đổi ngoại tệ.\n\nĐiều 3. Địa điểm đặt Đại lý đổi ngoại tệ\n\n1. Cơ sở lưu trú du lịch (bao gồm các khách sạn, các khu nghỉ dưỡng cao cấp v.v…) đã được cơ quan quản lý nhà nước về du lịch xếp hạng từ 3 (ba) sao trở lên;\n\n2. Cửa khẩu quốc tế (đường bộ, đường không, đường thủy);\n\n3. Khu vui chơi giải trí có thưởng dành riêng cho người nước ngoài;\n\n4. Văn phòng bán vé của các hãng hàng không, hàng hải, du lịch của nước ngoài và văn phòng bán vé quốc tế của các hãng hàng không Việt Nam;\n\n5. Khu du lịch, trung tâm thương mại, siêu thị có nhiều khách nước ngoài tham quan, mua sắm.\n\nĐiều 4. Hoạt động của Đại lý đổi ngoại tệ.\n\n1. Các đại lý đổi ngoại tệ chỉ được hoạt động dưới hình thức dùng Đồng Việt Nam mua ngoại tệ tiền mặt của cá nhân và không được bán ngoại tệ tiền mặt cho cá nhân lấy đồng Việt Nam (trừ các Đại lý đổi ngoại tệ đặt tại các khu cách ly ở các cửa khẩu quốc tế).\n\n2. Các Đại lý đổi ngoại tệ đặt tại các khu cách ly ở các cửa khẩu quốc tế được  ...

# %%
# ─── Option B: dùng custom data (uncomment + chỉnh) ───
# from datasets import Dataset
# my_data = [
#     {"instruction": "...", "input": "", "output": "..."},
#     # ... 100-500 examples
# ]
# raw = Dataset.from_list(my_data)
# print(f"✓ Custom dataset: {len(raw)} samples")

# %%
def format_alpaca(example):
    # Extract from 'conversations' list
    convs = example.get('conversations', [])
    instr = ""
    out = ""

    for msg in convs:
        if msg['role'] == 'user':
            instr = msg['content']
        elif msg['role'] == 'assistant':
            out = msg['content']

    text = ALPACA_TEMPLATE_NO_INPUT.format(instruction=instr.strip(), output=out.strip())
    return {"text": text}

ds = raw.map(format_alpaca, remove_columns=raw.column_names)
print("\n--- Formatted sample ---")
print(ds[0]["text"][:500])
# Out:
# Map:   0%|          | 0/300 [00:00<?, ? examples/s]
# --- Formatted sample ---
# ### Instruction:
# Phân tích thực tiễn:
#
# QUYẾT ĐỊNH
#
# CỦA NGÂN HÀNG NHÀ NƯỚC
#
# SỐ 21/2008/QĐ-NHNN NGÀY 11 THÁNG 7 NĂM 2008
#
# Ban hành quy chế đại lý đổi ngoại tệ
#
# _____________________
#
# THỐNG ĐỐC NGÂN HÀNG NHÀ NƯỚC
#
# Căn cứ Luật Ngân hàng Nhà nước Việt Nam năm 1997 và Luật sửa đổi, bổ sung một số điều của Luật Ngân hàng Nhà nước Việt Nam năm 2003;
#
# Căn cứ Pháp lệnh Ngoại hối năm 2005;
#
# Căn cứ Nghị định số 160/2006/NĐ-CP ngày 28/12/2006 của Chính phủ quy định chi tiết thi hành Pháp lệnh ngoại hối;
#
# Căn

# %%
# Token length analysis → set max_seq_length = p95
import numpy as np
import matplotlib.pyplot as plt
from transformers import AutoTokenizer

MODEL_NAME = "unsloth/Qwen2.5-3B-bnb-4bit"
MAX_SEQ_CAP = 1024  # hard cap cho profile T4

tok = AutoTokenizer.from_pretrained(MODEL_NAME)
lengths = [len(tok.encode(x["text"])) for x in ds]

p50 = int(np.percentile(lengths, 50))
p95 = int(np.percentile(lengths, 95))
p99 = int(np.percentile(lengths, 99))

print(f"Token length distribution:")
print(f"  min={min(lengths)}, max={max(lengths)}")
print(f"  p50={p50}, p95={p95}, p99={p99}")

# Round up to power of 2, capped at MAX_SEQ_CAP
MAX_SEQ_LENGTH = min(MAX_SEQ_CAP, 1 << (max(p95, 256) - 1).bit_length())
print(f"\n✓ Chọn max_seq_length = {MAX_SEQ_LENGTH} (cap = {MAX_SEQ_CAP})")

plt.figure(figsize=(8, 3))
plt.hist(lengths, bins=40, color='#0E2A52', edgecolor='white')
plt.axvline(p95, color='#C8102E', linestyle='--', label=f'p95 = {p95}')
plt.axvline(MAX_SEQ_LENGTH, color='green', linestyle='--', label=f'chosen = {MAX_SEQ_LENGTH}')
plt.xlabel('Tokens'); plt.ylabel('Count'); plt.title('Token length distribution')
plt.legend(); plt.tight_layout(); plt.show()
# Out:
# config.json:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/4.71k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# Token length distribution:
#   min=6, max=6
#   p50=6, p95=6, p99=6
#
# ✓ Chọn max_seq_length = 256 (cap = 1024)

# %%
# 90/10 train/eval split
split = ds.train_test_split(test_size=0.1, seed=42)
train_ds = split["train"]
eval_ds = split["test"]
print(f"✓ Train: {len(train_ds)}  |  Eval: {len(eval_ds)}")
# Out:
# ✓ Train: 270  |  Eval: 30

# %% [markdown]
# ## 2. Load Model + Configure LoRA (Baseline `r=16`)
#
# Dùng Unsloth `FastLanguageModel` để load **Qwen2.5-3B** đã pre-quantize 4-bit (NF4). Unsloth tự động bật custom CUDA kernels.
#
# PEFT config:
# - `r=16` (rank — baseline)
# - `lora_alpha=32` (scaling — alpha/r = 2)
# - `target_modules=["q_proj", "v_proj"]` per lab spec

# %%
from unsloth import FastLanguageModel

def load_base_model():
    """Reload base model — gọi mỗi lần train với rank khác để start từ scratch."""
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name=MODEL_NAME,
        max_seq_length=MAX_SEQ_LENGTH,
        dtype=None,            # auto: bf16 trên Ampere+, fp16 trên T4
        load_in_4bit=True,     # QLoRA
    )
    return model, tokenizer

def wrap_with_lora(model, r, alpha):
    """Wrap model với LoRA adapter."""
    return FastLanguageModel.get_peft_model(
        model,
        r=r,
        lora_alpha=alpha,
        target_modules=["q_proj", "v_proj"],  # lab spec
        lora_dropout=0,
        bias="none",
        use_gradient_checkpointing="unsloth",  # -60% VRAM
        random_state=42,
    )

# Load base + wrap với r=16 baseline
base_model, tokenizer = load_base_model()
model = wrap_with_lora(base_model, r=16, alpha=32)

trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
total = sum(p.numel() for p in model.parameters())
print(f"\n✓ Trainable: {trainable:,} ({100*trainable/total:.3f}% of {total:,})")
# Out:
# /usr/local/lib/python3.12/dist-packages/unsloth/__init__.py:153: UserWarning: WARNING: Unsloth should be imported before [transformers] to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from ._gpu_init import *
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: Could not find `steps_per_generation` in grpo_trainer
# Unsloth: Could not find `generation_batch_size` in grpo_trainer
# ==((====))==  Unsloth 2026.6.9: Fast Qwen2 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.11.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/2.05G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/171 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/4.71k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# Unsloth: pad_token was a vision token (<|vision_pad|>) on a text-only model. Replaced with <|endoftext|> to avoid NaN losses.
# unsloth/Qwen2.5-3B-bnb-4bit does not have a padding token! Will use pad_token = <|PAD_TOKEN|>.
# Not an error, but Unsloth cannot patch MLP layers with our manual autograd engine since either LoRA adapters
# are not enabled or a bias term (like in Qwen) is used.
# Not an error, but Unsloth cannot patch O projection layer with our manual autograd engine since either LoRA adapters
# are not enabled or a bias term (like in Qwen) is used.
# Unsloth 2026.6.9 patched 36 layers with 36 QKV layers, 0 O layers and 0 MLP layers.
# ✓ Trainable: 3,686,400 (0.217% of 1,702,359,040)

# %% [markdown]
# ## 3. Train Baseline (`r=16`) với TRL SFTTrainer
#
# - 3 epochs, cosine LR schedule, packing=True
# - Train batch = 1, grad_accum = 8 (effective batch = 8)
# - Eval strategy: "no"  # T4 không đủ VRAM cho mid-train eval

# %%
from trl import SFTTrainer
from transformers import TrainingArguments, Trainer
import inspect, time, trl, transformers

print(f"trl: {trl.__version__}  |  transformers: {transformers.__version__}")

# ── Aggressive fix: alias tokenizer→processing_class for old TRL + new transformers ──
import unsloth.models._utils as _u_utils
_underlying_init = getattr(_u_utils, "_original_trainer_init", Trainer.__init__)
if not getattr(_underlying_init, "_aliased", False):
    def _aliased_trainer_init(self, *args, **kwargs):
        if "tokenizer" in kwargs and "processing_class" not in kwargs:
            kwargs["processing_class"] = kwargs.pop("tokenizer")
        return _underlying_init(self, *args, **kwargs)
    _aliased_trainer_init._aliased = True
    _u_utils._original_trainer_init = _aliased_trainer_init
    if "tokenizer" not in inspect.signature(Trainer.__init__).parameters:
        _orig_t = Trainer.__init__
        def _t_init(self, *args, **kwargs):
            if "tokenizer" in kwargs and "processing_class" not in kwargs:
                kwargs["processing_class"] = kwargs.pop("tokenizer")
            return _orig_t(self, *args, **kwargs)
        _t_init._aliased = True
        Trainer.__init__ = _t_init
    print("✓ Trainer.__init__ patched")

try:
    from trl import SFTConfig
    _HAS_SFTCONFIG = True
except ImportError:
    _HAS_SFTCONFIG = False

_TA_PARAMS = inspect.signature(TrainingArguments.__init__).parameters
_EVAL_KEY = "eval_strategy" if "eval_strategy" in _TA_PARAMS else "evaluation_strategy"
_SFT_PARAMS = inspect.signature(SFTTrainer.__init__).parameters
_SUPPORTS_OLD_KWARGS = "dataset_text_field" in _SFT_PARAMS

def make_trainer(model, tokenizer, train_ds, eval_ds, output_subdir, **overrides):
    base_kwargs = dict(
        output_dir=os.path.join(OUTPUT_DIR, output_subdir),
        per_device_train_batch_size=1,
        per_device_eval_batch_size=1,
        eval_accumulation_steps=4,
        prediction_loss_only=True,
        gradient_accumulation_steps=8,
        warmup_ratio=0.10,
        num_train_epochs=3,
        learning_rate=2e-4,
        lr_scheduler_type="cosine",
        fp16=not torch.cuda.is_bf16_supported(),
        bf16=torch.cuda.is_bf16_supported(),
        logging_steps=5,
        eval_steps=25,
        save_strategy="epoch",
        optim="adamw_8bit",
        weight_decay=0.01,
        seed=42,
        report_to="none",
    )
    base_kwargs[_EVAL_KEY] = "no"  # T4 không đủ VRAM cho mid-train eval
    base_kwargs.update(overrides)

    if _HAS_SFTCONFIG:
        sft_extra = dict(dataset_text_field="text", packing=False, max_seq_length=MAX_SEQ_LENGTH)
        sft_params = inspect.signature(SFTConfig.__init__).parameters
        sft_extra = {k: v for k, v in sft_extra.items() if k in sft_params}
        valid_base = {k: v for k, v in base_kwargs.items() if k in sft_params}
        args = SFTConfig(**valid_base, **sft_extra)
    else:
        args = TrainingArguments(**base_kwargs)

    trainer_kwargs = {
        "model": model, "train_dataset": train_ds, "eval_dataset": eval_ds, "args": args,
    }
    if "processing_class" in _SFT_PARAMS:
        trainer_kwargs["processing_class"] = tokenizer
    else:
        trainer_kwargs["tokenizer"] = tokenizer
    if _SUPPORTS_OLD_KWARGS:
        trainer_kwargs.update(dict(dataset_text_field="text", max_seq_length=MAX_SEQ_LENGTH, packing=False))
    return SFTTrainer(**trainer_kwargs)

def safe_evaluate(trainer):
    """Robust eval — handles NotebookProgressCallback bug + OOM."""
    import gc as _gc
    _gc.collect(); torch.cuda.empty_cache()

    # Remove buggy notebook callback that breaks evaluate-after-train
    try:
        from transformers.utils.notebook import NotebookProgressCallback
        trainer.remove_callback(NotebookProgressCallback)
    except Exception:
        pass

    # Try standard evaluate first
    try:
        return trainer.evaluate()["eval_loss"]
    except (torch.cuda.OutOfMemoryError, RuntimeError) as e:
        print(f"⚠ trainer.evaluate() failed ({type(e).__name__}). Falling back to manual eval...")

    # Manual eval loop — bulletproof
    _gc.collect(); torch.cuda.empty_cache()
    m = trainer.model
    m.eval()
    eval_dl = trainer.get_eval_dataloader()
    total, n = 0.0, 0
    with torch.no_grad():
        for batch in eval_dl:
            batch = {k: v.to(m.device) for k, v in batch.items() if hasattr(v, "to")}
            out = m(**batch)
            total += out.loss.item(); n += 1
            del out; torch.cuda.empty_cache()
    return total / max(n, 1)
# Out:
# trl: 0.15.2  |  transformers: 5.5.0
# ✓ Trainer.__init__ patched

# %%
# Train baseline r=16
import gc
torch.cuda.reset_peak_memory_stats()
trainer_16 = make_trainer(model, tokenizer, train_ds, eval_ds, "r16")

t0 = time.time()
result_16 = trainer_16.train()
wall_16 = time.time() - t0
vram_16 = torch.cuda.max_memory_allocated() / 1e9

print(f"\n✓ r=16 done in {wall_16/60:.1f} min, peak VRAM = {vram_16:.1f} GB")
trainer_16.save_model(os.path.join(OUTPUT_DIR, "r16"))

# Compute eval — guarded so eval_loss_16/ppl_16 are always defined
try:
    eval_loss_16 = safe_evaluate(trainer_16)
    ppl_16 = float(np.exp(eval_loss_16))
    print(f"✓ r=16 eval loss = {eval_loss_16:.4f}, perplexity = {ppl_16:.2f}")
except Exception as e:
    print(f"⚠ Eval failed: {e}. Setting NaN — recover later by reloading adapter.")
    eval_loss_16 = float("nan")
    ppl_16 = float("nan")
# Out:
# warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# Unsloth: Tokenizing ["text"] (num_proc=6):   0%|          | 0/270 [00:00<?, ? examples/s]
# Unsloth: Tokenizing ["text"] (num_proc=6):   0%|          | 0/30 [00:00<?, ? examples/s]
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None}.
# 🦥 Unsloth: Padding-free auto-enabled, enabling faster training.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 270 | Num Epochs = 3 | Total steps = 102
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 8
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 8 x 1) = 8
#  "-____-"     Trainable parameters = 3,686,400 of 3,089,625,088 (0.12% trained)
# `use_return_dict` is deprecated! Use `return_dict` instead!
#     <div>
#
#       <progress value='102' max='102' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [102/102 04:41, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>6.608044</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>6.026478</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>3.903829</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.684411</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.678333</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.332292</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.945140</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.392564</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.061002</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.002391</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.000332</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.000171</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.000109</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.000085</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.000073</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.000067</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.000063</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.000061</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.000060</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.000060</td>
#     </tr>
#   </tbody>
# </table><p>
# Unsloth: Restored added_tokens_decoder metadata in /content/lab21_lora_t4/r16/checkpoint-34/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in /content/lab21_lora_t4/r16/checkpoint-68/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in /content/lab21_lora_t4/r16/checkpoint-102/tokenizer_config.json.
# ✓ r=16 done in 5.0 min, peak VRAM = 2.2 GB
# Unsloth: Restored added_tokens_decoder metadata in /content/lab21_lora_t4/r16/tokenizer_config.json.
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# ✓ r=16 eval loss = 0.0000, perplexity = 1.00

# %%
# Plot training loss để detect overfitting
import pandas as pd

def plot_losses(log_history, title="Training Loss"):
    df = pd.DataFrame(log_history)
    train = df[df["loss"].notna()] if "loss" in df else pd.DataFrame()
    eval_ = df[df["eval_loss"].notna()] if "eval_loss" in df else pd.DataFrame()
    plt.figure(figsize=(8, 4))
    if not train.empty:
        plt.plot(train["step"], train["loss"], label="train", color="#0E2A52")
    if not eval_.empty:
        plt.plot(eval_["step"], eval_["eval_loss"], label="eval", color="#C8102E", marker="o")
    plt.xlabel("Step"); plt.ylabel("Loss"); plt.title(title)
    plt.legend(); plt.grid(alpha=0.3); plt.tight_layout(); plt.show()

plot_losses(trainer_16.state.log_history, title="Loss Curve — r=16")
print("\n📌 T4 mode: eval-during-training tắt để tiết kiệm VRAM. Chỉ có train loss curve.")
# Out:
# 📌 T4 mode: eval-during-training tắt để tiết kiệm VRAM. Chỉ có train loss curve.

# %% [markdown]
# ## 4. Rank Experiment — `r=8` vs `r=64`
#
# Train 2 adapters thêm với rank khác để hiểu trade-off:
# - **`r=8`** — chỉ ~0.05% params, train nhanh, ít VRAM
# - **`r=64`** — ~0.4% params, gần full fine-tune, tốn VRAM hơn

# %%
def train_one_rank(r, alpha):
    """Train fresh adapter với rank cụ thể, return metrics."""
    gc.collect(); torch.cuda.empty_cache()
    torch.cuda.reset_peak_memory_stats()

    base_m, tok = load_base_model()
    m = wrap_with_lora(base_m, r=r, alpha=alpha)
    trainable = sum(p.numel() for p in m.parameters() if p.requires_grad)

    tr = make_trainer(m, tok, train_ds, eval_ds, f"r{r}")
    t0 = time.time()
    tr.train()
    wall = time.time() - t0
    vram = torch.cuda.max_memory_allocated() / 1e9

    # Save adapter BEFORE eval — eval may OOM but we want the checkpoint
    tr.save_model(os.path.join(OUTPUT_DIR, f"r{r}"))
    print(f"✓ r={r} adapter saved. Computing eval loss...")

    try:
        eval_loss = safe_evaluate(tr)
    except Exception as e:
        print(f"⚠ Eval failed: {e}. Setting eval_loss=NaN.")
        eval_loss = float('nan')

    return {
        "rank": r, "alpha": alpha, "trainable_params": trainable,
        "train_time_min": wall / 60, "peak_vram_gb": vram,
        "eval_loss": eval_loss,
        "eval_perplexity": float(np.exp(eval_loss)) if not np.isnan(eval_loss) else float('nan'),
        "trainer": tr, "model": m, "tokenizer": tok,
    }

# %%
# Cleanup baseline before training rank experiments
del trainer_16, model, base_model
gc.collect(); torch.cuda.empty_cache()

print("\n========== Training r=8 ==========")
exp_8 = train_one_rank(r=8, alpha=16)
# Out:
# ========== Training r=8 ==========
# ==((====))==  Unsloth 2026.6.9: Fast Qwen2 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.11.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# Unsloth: pad_token was a vision token (<|vision_pad|>) on a text-only model. Replaced with <|endoftext|> to avoid NaN losses.
# unsloth/Qwen2.5-3B-bnb-4bit does not have a padding token! Will use pad_token = <|PAD_TOKEN|>.
# warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# Unsloth: Tokenizing ["text"] (num_proc=5):   0%|          | 0/270 [00:00<?, ? examples/s]
# Unsloth: Tokenizing ["text"] (num_proc=5):   0%|          | 0/30 [00:00<?, ? examples/s]
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None}.
# 🦥 Unsloth: Padding-free auto-enabled, enabling faster training.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 270 | Num Epochs = 3 | Total steps = 102
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 8
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 8 x 1) = 8
#  "-____-"     Trainable parameters = 1,843,200 of 3,087,781,888 (0.06% trained)
#     <div>
#
#       <progress value='102' max='102' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [102/102 04:19, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>6.619025</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>6.334139</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>4.945311</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>3.363313</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>2.592658</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.843950</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.463532</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.220181</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.939523</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.550267</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.284063</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.087580</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.016191</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.003492</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.001526</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.000985</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.000774</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.000701</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.000664</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.000661</td>
#     </tr>
#   </tbody>
# </table><p>
# Unsloth: Restored added_tokens_decoder metadata in /content/lab21_lora_t4/r8/checkpoint-34/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in /content/lab21_lora_t4/r8/checkpoint-68/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in /content/lab21_lora_t4/r8/checkpoint-102/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in /content/lab21_lora_t4/r8/tokenizer_config.json.
# ✓ r=8 adapter saved. Computing eval loss...
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)

# %%
# Cleanup r=8 references
del exp_8["trainer"], exp_8["model"]
gc.collect(); torch.cuda.empty_cache()

print("\n========== Training r=64 ==========")
exp_64 = train_one_rank(r=64, alpha=128)
# Out:
# ========== Training r=64 ==========
# ==((====))==  Unsloth 2026.6.9: Fast Qwen2 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.11.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# Unsloth: pad_token was a vision token (<|vision_pad|>) on a text-only model. Replaced with <|endoftext|> to avoid NaN losses.
# unsloth/Qwen2.5-3B-bnb-4bit does not have a padding token! Will use pad_token = <|PAD_TOKEN|>.
# warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None}.
# 🦥 Unsloth: Padding-free auto-enabled, enabling faster training.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 270 | Num Epochs = 3 | Total steps = 102
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 8
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 8 x 1) = 8
#  "-____-"     Trainable parameters = 14,745,600 of 3,100,684,288 (0.48% trained)
#     <div>
#
#       <progress value='102' max='102' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [102/102 04:31, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>6.535046</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>4.554188</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.423658</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.436998</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>3.747035</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.674859</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.009625</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.000180</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.000047</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.000031</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.000025</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.000020</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.000017</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.000015</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.000014</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.000013</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.000012</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.000012</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.000012</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.000011</td>
#     </tr>
#   </tbody>
# </table><p>
# Unsloth: Restored added_tokens_decoder metadata in /content/lab21_lora_t4/r64/checkpoint-34/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in /content/lab21_lora_t4/r64/checkpoint-68/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in /content/lab21_lora_t4/r64/checkpoint-102/tokenizer_config.json.
# Unsloth: Restored added_tokens_decoder metadata in /content/lab21_lora_t4/r64/tokenizer_config.json.
# ✓ r=64 adapter saved. Computing eval loss...
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)

# %%
# Cleanup r=64 references
del exp_64["trainer"], exp_64["model"]
gc.collect(); torch.cuda.empty_cache()

# Build summary table
results = [
    {"rank": 16, "alpha": 32, "trainable_params": int(trainable),
     "train_time_min": wall_16/60, "peak_vram_gb": vram_16,
     "eval_loss": eval_loss_16, "eval_perplexity": ppl_16},
    {k: v for k, v in exp_8.items() if k not in ("trainer","model","tokenizer")},
    {k: v for k, v in exp_64.items() if k not in ("trainer","model","tokenizer")},
]
summary_df = pd.DataFrame(results).sort_values("rank").reset_index(drop=True)
print("\n=== Rank Experiment Summary ===")
print(summary_df.to_string(index=False))
# Out:
# === Rank Experiment Summary ===
#  rank  alpha  trainable_params  train_time_min  peak_vram_gb  eval_loss  eval_perplexity
#     8     16           1843200        4.408749      2.822115   0.000538         1.000538
#    16     32           3686400        4.976760      2.221367   0.000049         1.000049
#    64    128          14745600        4.603359      3.599499   0.000010         1.000010

# %% [markdown]
# ## 5. Evaluation — Qualitative Comparison
#
# Generate test prompts và so sánh fine-tuned vs base model trên 5 prompts (chạy full 20 nếu thời gian cho phép).

# %%
TEST_PROMPTS = [
    "Giải thích khái niệm machine learning cho người mới bắt đầu.",
    "Viết đoạn code Python tính số Fibonacci thứ n.",
    "Liệt kê 5 nguyên tắc thiết kế UI/UX.",
    "Tóm tắt sự khác biệt giữa LoRA và QLoRA.",
    "Phân biệt prompt engineering, RAG, và fine-tuning.",
    "Khi nào nên dùng RAG thay vì fine-tuning?",
    "Giải thích cách hoạt động của Flash Attention.",
    "List 3 câu hỏi phỏng vấn cho ML Engineer junior.",
    "Cho biết ưu điểm của Transformer so với RNN.",
    "Cách evaluate performance của một LLM fine-tuned model?",
]
print(f"✓ {len(TEST_PROMPTS)} test prompts")
# Out:
# ✓ 10 test prompts

# %%
from peft import PeftModel

def generate_response(model, tokenizer, prompt, max_new_tokens=200):
    FastLanguageModel.for_inference(model)
    text = ALPACA_TEMPLATE_NO_INPUT.format(instruction=prompt, output="")
    inputs = tokenizer(text, return_tensors="pt").to("cuda")
    out = model.generate(**inputs, max_new_tokens=max_new_tokens,
        temperature=0.7, top_p=0.9, do_sample=True,
        pad_token_id=tokenizer.eos_token_id)
    full = tokenizer.decode(out[0], skip_special_tokens=True)
    return full.split("### Response:")[-1].strip()

# Reload base + r=16 adapter
base_for_eval, tok_for_eval = load_base_model()
ft_model = PeftModel.from_pretrained(base_for_eval, os.path.join(OUTPUT_DIR, "r16"))

qualitative_results = []
for i, prompt in enumerate(TEST_PROMPTS[:5]):
    print(f"\n━━━ Prompt {i+1}: {prompt[:80]}...")
    base_resp = generate_response(base_for_eval, tok_for_eval, prompt)
    ft_resp = generate_response(ft_model, tok_for_eval, prompt)
    qualitative_results.append({
        "prompt": prompt, "base": base_resp[:300], "finetuned": ft_resp[:300],
    })
    print(f"  BASE: {base_resp[:200]}...")
    print(f"  FT  : {ft_resp[:200]}...")
# Out:
# ==((====))==  Unsloth 2026.6.9: Fast Qwen2 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.11.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# Unsloth: pad_token was a vision token (<|vision_pad|>) on a text-only model. Replaced with <|endoftext|> to avoid NaN losses.
# unsloth/Qwen2.5-3B-bnb-4bit does not have a padding token! Will use pad_token = <|PAD_TOKEN|>.
# Both `max_new_tokens` (=200) and `max_length`(=32768) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ━━━ Prompt 1: Giải thích khái niệm machine learning cho người mới bắt đầu....
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# Both `max_new_tokens` (=200) and `max_length`(=32768) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=200) and `max_length`(=32768) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#   BASE: Machine learning là một kỹ thuật trong trí thông minhhệ máy tính để máy tự học và cải thiện bằng việc tiếp nhận dữ liệu và thực hiện phân tích, dự đoán kết quả dựa trên những gì đã học được. Nó giúp m...
#   FT  : Machine learning là một loại trí thông minhell, giúp máy tự động học và cải thiện qua thời gian. Nó sử dụng thuật toán và mô hình toán học để phân tích dữ liệu và đưa ra dự đoán dựa trên những gì đã h...
#
# ━━━ Prompt 2: Viết đoạn code Python tính số Fibonacci thứ n....
# Both `max_new_tokens` (=200) and `max_length`(=32768) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=200) and `max_length`(=32768) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#   BASE: def fibonacci(n):
#     if n <= 0:
#         print("Nhập số nguyên dương!")
#     elif n == 1:
#         return 0
#     elif n == 2:
#         return 1
#     else:
#         a, b = 0, 1
#         for i in range(2, n):
# ...
#   FT  : # Instruction:
# Viết đoạn code Python tính số Fibonacci thứ n.
#
# # Response:
# def fibonacci(n):
#     if n < 0:
#         print("Input is not a positive integer.")
#     elif n == 0:
#         return 0
#     elif ...
#
# ━━━ Prompt 3: Liệt kê 5 nguyên tắc thiết kế UI/UX....
# Both `max_new_tokens` (=200) and `max_length`(=32768) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=200) and `max_length`(=32768) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#   BASE: 1. Người dùng là trung tâm: Thiết kế UI/UX phải tập trung vào nhu cầu và trải nghiệm của người dùng, tạo ra trải nghiệm tốt nhất cho họ.
# 2. Đơn giản và trực quan: UI/UX phải đơn giản và dễ sử dụng, tr...
#   FT  : 1. Thỏa mãn nhu cầu người dùng: UI/UX phải đáp ứng nhu cầu của người dùng, tạo ra trải nghiệm tốt nhất cho người dùng.
# 2. Hiệu quả: UI/UX phải mang lại hiệu quả ca diệp cho người dùng, giúp họ hoàn th...
#
# ━━━ Prompt 4: Tóm tắt sự khác biệt giữa LoRA và QLoRA....
# Both `max_new_tokens` (=200) and `max_length`(=32768) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=200) and `max_length`(=32768) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#   BASE: LoRA (Low-Rank Adaptation) và QLoRA (Quantized LoRA) là hai phương pháp cải tiến để tăng hiệu quả của các mô hình NLU (Nội dung Thuyết Trí Tuệ Máy học). LoRA là một phương pháp được sử dụng để làm cho...
#   FT  : LoRA và QLoRA là hai phương pháp cải thiện hiệu suất của các mô hình NLU (Nền Tảng Học Lượng). LoRA cải thiện hiệu suất của các mô hình NLU bằng cách thêm một số lớp mới vào mô hình, trong khi QLoRA c...
#
# ━━━ Prompt 5: Phân biệt prompt engineering, RAG, và fine-tuning....
# Both `max_new_tokens` (=200) and `max_length`(=32768) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#   BASE: Prompt Engineering là một kỹ thuật trong lập trí máy học (ML) để cải thiện hiệu suất của mô hình bằng cách tối ưu hóa việc cung cấp dữ liệu cho mô hình. RAG (Relevant, Augmented, and Generated) là một...
#   FT  : Prompt Engineering là kỹ thuật để cải thiện hiệu suất của mô hình ngôn ngữ bằng cách cải tiến lời đề nghị của người dùng để mô hình có thể hiểu và xử lý yêu cầu của người dùng tốt hơn. RAG là một thuậ...

# %%
qual_df = pd.DataFrame(qualitative_results)
qual_df.to_csv(os.path.join(OUTPUT_DIR, "qualitative_comparison.csv"), index=False)
print(qual_df.head())
# Out:
#                                               prompt  \
# 0  Giải thích khái niệm machine learning cho ngườ...
# 1     Viết đoạn code Python tính số Fibonacci thứ n.
# 2               Liệt kê 5 nguyên tắc thiết kế UI/UX.
# 3           Tóm tắt sự khác biệt giữa LoRA và QLoRA.
# 4  Phân biệt prompt engineering, RAG, và fine-tun...
#
#                                                 base  \
# 0  Machine learning là một kỹ thuật trong trí thô...
# 1  def fibonacci(n):\n    if n <= 0:\n        pri...
# 2  1. Người dùng là trung tâm: Thiết kế UI/UX phả...
# 3  LoRA (Low-Rank Adaptation) và QLoRA (Quantized...
# 4  Prompt Engineering là một kỹ thuật trong lập t...
#
#                                            finetuned
# 0  Machine learning là một loại trí thông minhell...
# 1  # Instruction:\nViết đoạn code Python tính số ...
# 2  1. Thỏa mãn nhu cầu người dùng: UI/UX phải đáp...
# 3  LoRA và QLoRA là hai phương pháp cải thiện hiệ...
# 4  Prompt Engineering là kỹ thuật để cải thiện hi...

# %% [markdown]
# ## 6. Save Adapters + Generate Report

# %%
summary_df.to_csv(os.path.join(OUTPUT_DIR, "rank_experiment_summary.csv"), index=False)

GPU_COST_USD_PER_HOUR = 0.35  # T4 default
total_minutes = summary_df["train_time_min"].sum()
total_cost = (total_minutes / 60) * GPU_COST_USD_PER_HOUR

print(f"\n✓ Tổng training time: {total_minutes:.1f} phút")
print(f"✓ Estimated cost: ${total_cost:.2f} (@ ${GPU_COST_USD_PER_HOUR}/hr)")
# Out:
# ✓ Tổng training time: 14.0 phút
# ✓ Estimated cost: $0.08 (@ $0.35/hr)

# %%
# # Optional: push adapter to HuggingFace Hub
# PUSH_TO_HUB = False
# HUB_REPO_ID = "your-username/qwen2.5-3b-vi-lab21-r16"

# if PUSH_TO_HUB:
#     from huggingface_hub import login
#     login()
#     ft_model.push_to_hub(HUB_REPO_ID)
#     tok_for_eval.push_to_hub(HUB_REPO_ID)
#     print(f"✓ Adapter pushed: https://huggingface.co/{HUB_REPO_ID}")

# %% [markdown]
# ## ✅ Done — Submission Checklist
#
# Trước khi nộp, verify đã có đủ trong `OUTPUT_DIR`:
#
# - [ ] `r8/` — adapter checkpoint
# - [ ] `r16/` — adapter checkpoint
# - [ ] `r64/` — adapter checkpoint
# - [ ] `rank_experiment_summary.csv` — bảng metrics
# - [ ] `qualitative_comparison.csv` — 5+ before/after examples
# - [ ] `REPORT.md` — đã điền phần "Kết luận"
#
# **Nộp**: zip `OUTPUT_DIR` + push code lên GitHub repo cá nhân, gửi link cho instructor.

# %%
## --- THỰC NGHIỆM RANK 8 ---
# 1. Dọn dẹp RAM trước khi train
import gc
import torch
try: del trainer_r8
except: pass
gc.collect()
torch.cuda.empty_cache()

# --- FIX: Reload base model because it was deleted in cleanup ---
model, tokenizer = load_base_model()

# 2. Khởi tạo lại model và áp dụng LoRA r=8
model_r8 = FastLanguageModel.get_peft_model(
    model,
    r = 8,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
    lora_alpha = 16,
    lora_dropout = 0,
    bias = "none",
    use_gradient_checkpointing = "unsloth",
    random_state = 3407,
    use_rslora = False,
    loftq_config = None,
)

# 3. Khởi tạo SFTTrainer
trainer_r8 = SFTTrainer(
    model = model_r8,
    tokenizer = tokenizer,
    train_dataset = train_ds,
    eval_dataset = eval_ds,
    dataset_text_field = "text",
    max_seq_length = MAX_SEQ_LENGTH,
    dataset_num_proc = 2,
    packing = False,
    args = TrainingArguments(
        per_device_train_batch_size = 1,
        gradient_accumulation_steps = 8,
        warmup_ratio = 0.1,
        num_train_epochs = 3,
        learning_rate = 2e-4,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "cosine",
        seed = 3407,
        output_dir = "outputs_r8",
        report_to = "none",
        eval_strategy = "no",
    ),
)

# 4. Train
import time
start_time = time.time()
trainer_r8_stats = trainer_r8.train()
end_time = time.time()
print(f"✓ Train time (r=8): {(end_time - start_time)/60:.2f} phút")
print(f"✓ Peak VRAM: {torch.cuda.max_memory_allocated() / 1024**3:.2f} GB")
# Out:
# ==((====))==  Unsloth 2026.6.9: Fast Qwen2 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.11.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# Unsloth: pad_token was a vision token (<|vision_pad|>) on a text-only model. Replaced with <|endoftext|> to avoid NaN losses.
# unsloth/Qwen2.5-3B-bnb-4bit does not have a padding token! Will use pad_token = <|PAD_TOKEN|>.
# warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None}.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 270 | Num Epochs = 3 | Total steps = 102
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 8
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 8 x 1) = 8
#  "-____-"     Trainable parameters = 14,966,784 of 3,100,905,472 (0.48% trained)
#     <div>
#
#       <progress value='103' max='102' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [102/102 05:32, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>6.629956</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.629956</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.629956</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.567451</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>6.279244</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>5.738106</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.971488</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.821463</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.996330</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.515249</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.159517</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.297012</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.413689</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.066968</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.007332</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000681</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.000240</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.000130</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.000077</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000053</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.000040</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.000033</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.000032</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.000031</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.000030</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.000028</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.000025</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.000022</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.000019</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.000017</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.000016</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.000015</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.000015</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.000014</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.000013</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.000012</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.000011</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.000011</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.000010</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.000009</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.000008</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.000007</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.000007</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.000006</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.000006</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.000005</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.000005</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.000005</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.000004</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.000004</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.000004</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.000004</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.000004</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.000004</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.000003</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.000003</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.000003</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.000003</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.000003</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.000003</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.000003</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.000003</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.000003</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.000003</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.000003</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.000003</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.000002</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>0.000002</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# /tmp/ipykernel_638/1169079356.py in <cell line: 0>()
#      57 import time
#      58 start_time = time.time()
# ---> 59 trainer_r8_stats = trainer_r8.train()
#      60 end_time = time.time()
#      61 print(f"✓ Train time (r=8): {(end_time - start_time)/60:.2f} phút")
#
# /usr/local/lib/python3.12/dist-packages/unsloth/trainer.py in _train_with_reset(*train_args, **train_kwargs)
#     614                     except Exception:
#     615                         pass
# --> 616                     return _orig_train(*train_args, **train_kwargs)
#     617
#     618                 self.train = _train_with_reset
#
# /content/unsloth_compiled_cache/UnslothSFTTrainer.py in wrapper(self, *args, **kwargs)
#      93         if hasattr(self, 'model') and hasattr(self.model, "for_training"):
#      94             self.model.for_training(use_gradient_checkpointing=use_gc)
# ---> 95         output = f(self, *args, **kwargs)
#      96         # Restore previous mode when possible
#      97         if hasattr(self, 'model') and hasattr(self.model, "for_inference"):
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1422         ctx = suppress_progress_bars() if args.push_to_hub else contextlib.nullcontext()
#    1423         with ctx:
# -> 1424             return inner_training_loop(
#    1425                 args=args,
#    1426                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.12/dist-packages/unsloth/models/llama.py in _fast_inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in _run_epoch(self, model, epoch, train_dataloader, steps_in_epoch, num_update_steps_per_epoch, trial, ignore_keys_for_eval, start_time, resume_from_checkpoint, epochs_trained, steps_trained_in_current_epoch)
#    1773                     self.state.epoch = epoch + (step + 1) / steps_in_epoch
#    1774                     self.control = self.callback_handler.on_step_end(self.args, self.state, self.control)
# -> 1775                     self._maybe_log_save_evaluate(
#    1776                         self._tr_loss,
#    1777                         grad_norm,
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in _maybe_log_save_evaluate(self, tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval, start_time, learning_rate)
#    2086
#    2087         if self.control.should_save:
# -> 2088             self._save_checkpoint(model, trial)
#    2089             self.control = self.callback_handler.on_save(self.args, self.state, self.control)
#    2090
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in _save_checkpoint(self, model, trial)
#    3044         run_dir = self._get_output_dir(trial=trial)
#    3045         output_dir = os.path.join(run_dir, checkpoint_folder)
# -> 3046         self.save_model(output_dir, _internal_call=True)
#    3047
#    3048         if (
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in save_model(self, output_dir, _internal_call)
#    3795
#    3796         elif self.args.should_save:
# -> 3797             self._save(output_dir)
#    3798
#    3799         # Push to the Hub when `save_model` is called by the user.
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in _save(self, output_dir, state_dict)
#    3838
#    3839         # Good practice: save your training arguments together with the trained model
# -> 3840         torch.save(self.args, os.path.join(output_dir, TRAINING_ARGS_NAME))
#    3841
#    3842     # ---- Logging & Metrics ----
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#    1002     if _use_new_zipfile_serialization:
#    1003         with _open_zipfile_writer(f) as opened_zipfile:
# -> 1004             _save(
#    1005                 obj,
#    1006                 opened_zipfile,
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol, _disable_byteorder_record)
#    1252
#    1253     pickler = PyTorchPickler(data_buf, protocol=pickle_protocol)
# -> 1254     pickler.dump(obj)
#    1255
#    1256     # The class def keeps the persistent_id closure alive, leaking memory.
#
# PicklingError: Can't pickle <class 'trl.trainer.sft_config.SFTConfig'>: it's not the same object as trl.trainer.sft_config.SFTConfig

# %%
## --- THỰC NGHIỆM RANK 64 ---
# 1. Dọn dẹp RAM trước khi train
import gc
import torch
try: del trainer_r8
except: pass
gc.collect()
torch.cuda.empty_cache()

# 2. Khởi tạo lại model và áp dụng LoRA r=64
model_r64 = FastLanguageModel.get_peft_model(
    model,
    r = 64,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
    lora_alpha = 128,
    lora_dropout = 0,
    bias = "none",
    use_gradient_checkpointing = "unsloth",
    random_state = 3407,
    use_rslora = False,
    loftq_config = None,
)

# 3. Khởi tạo SFTTrainer
trainer_r64 = SFTTrainer(
    model = model_r64,
    tokenizer = tokenizer,
    train_dataset = train_ds,
    eval_dataset = eval_ds,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False,
    args = TrainingArguments(
        per_device_train_batch_size = 1,
        gradient_accumulation_steps = 8,
        warmup_ratio = 0.1,
        num_train_epochs = 3,
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "cosine",
        seed = 3407,
        output_dir = "outputs_r64",
        report_to = "none",
        eval_strategy = "no",
    ),
)

# 4. Train
import time
start_time = time.time()
trainer_r64_stats = trainer_r64.train()
end_time = time.time()
print(f"✓ Train time (r=64): {(end_time - start_time)/60:.2f} phút")
print(f"✓ Peak VRAM: {torch.cuda.max_memory_allocated() / 1024**3:.2f} GB")

# %%
## --- PUSH TO HUGGINGFACE HUB (OPTION B) ---
# Đảm bảo bạn đã lưu access token HF trên Colab Secrets với tên 'HF_TOKEN'
import os
from google.colab import userdata
from huggingface_hub import login

try:
    hf_token = userdata.get('HF_TOKEN')
    login(token=hf_token)

    # Push adapter r=16 (baseline) lên Hub. Bạn thay 'your_username' bằng tên thật
    # model.push_to_hub("your_username/lab21-Qwen2.5-3B-Legal-r16")
    print("✓ Login thành công. Hãy bỏ comment dòng push_to_hub và thay tên username để upload!")
except Exception as e:
    print("Vui lòng tạo HF_TOKEN trong tab Secrets (Biểu tượng chìa khóa) của Colab.")

# %%
import os

# Define paths
zip_filename = "lab21_lora_t4_submission.zip"
folder_to_zip = "/content/lab21_lora_t4"

# Create the zip file
# !zip -r {zip_filename} {folder_to_zip}

if os.path.exists(zip_filename):
    print(f"\n✓ Submission zip created successfully: {zip_filename}")
    print(f"✓ File size: {os.path.getsize(zip_filename) / 1024**2:.2f} MB")
else:
    print("\n❌ Error creating zip file.")
# Out:
#   adding: content/lab21_lora_t4/ (stored 0%)
#   adding: content/lab21_lora_t4/r8/ (stored 0%)
#   adding: content/lab21_lora_t4/r8/checkpoint-102/ (stored 0%)
#   adding: content/lab21_lora_t4/r8/checkpoint-102/trainer_state.json (deflated 71%)
#   adding: content/lab21_lora_t4/r8/checkpoint-102/rng_state.pth (deflated 27%)
#   adding: content/lab21_lora_t4/r8/checkpoint-102/adapter_model.safetensors (deflated 8%)
#   adding: content/lab21_lora_t4/r8/checkpoint-102/tokenizer_config.json (deflated 89%)
#   adding: content/lab21_lora_t4/r8/checkpoint-102/scheduler.pt (deflated 62%)
#   adding: content/lab21_lora_t4/r8/checkpoint-102/tokenizer.json (deflated 81%)
#   adding: content/lab21_lora_t4/r8/checkpoint-102/README.md (deflated 65%)
#   adding: content/lab21_lora_t4/r8/checkpoint-102/adapter_config.json (deflated 57%)
#   adding: content/lab21_lora_t4/r8/checkpoint-102/scaler.pt (deflated 64%)
#   adding: content/lab21_lora_t4/r8/checkpoint-102/optimizer.pt (deflated 10%)
#   adding: content/lab21_lora_t4/r8/checkpoint-102/training_args.bin (deflated 53%)
#   adding: content/lab21_lora_t4/r8/adapter_model.safetensors (deflated 8%)
#   adding: content/lab21_lora_t4/r8/tokenizer_config.json (deflated 89%)
#   adding: content/lab21_lora_t4/r8/checkpoint-34/ (stored 0%)
#   adding: content/lab21_lora_t4/r8/checkpoint-34/trainer_state.json (deflated 64%)
#   adding: content/lab21_lora_t4/r8/checkpoint-34/rng_state.pth (deflated 26%)
#   adding: content/lab21_lora_t4/r8/checkpoint-34/adapter_model.safetensors (deflated 8%)
#   adding: content/lab21_lora_t4/r8/checkpoint-34/tokenizer_config.json (deflated 89%)
#   adding: content/lab21_lora_t4/r8/checkpoint-34/scheduler.pt (deflated 61%)
#   adding: content/lab21_lora_t4/r8/checkpoint-34/tokenizer.json (deflated 81%)
#   adding: content/lab21_lora_t4/r8/checkpoint-34/README.md (deflated 65%)
#   adding: content/lab21_lora_t4/r8/checkpoint-34/adapter_config.json (deflated 57%)
#   adding: content/lab21_lora_t4/r8/checkpoint-34/scaler.pt (deflated 64%)
#   adding: content/lab21_lora_t4/r8/checkpoint-34/optimizer.pt (deflated 9%)
#   adding: content/lab21_lora_t4/r8/checkpoint-34/training_args.bin (deflated 53%)
#   adding: content/lab21_lora_t4/r8/checkpoint-68/ (stored 0%)
#   adding: content/lab21_lora_t4/r8/checkpoint-68/trainer_state.json (deflated 69%)
#   adding: content/lab21_lora_t4/r8/checkpoint-68/rng_state.pth (deflated 27%)
#   adding: content/lab21_lora_t4/r8/checkpoint-68/adapter_model.safetensors (deflated 8%)
#   adding: content/lab21_lora_t4/r8/checkpoint-68/tokenizer_config.json (deflated 89%)
#   adding: content/lab21_lora_t4/r8/checkpoint-68/scheduler.pt (deflated 61%)
#   adding: content/lab21_lora_t4/r8/checkpoint-68/tokenizer.json (deflated 81%)
#   adding: content/lab21_lora_t4/r8/checkpoint-68/README.md (deflated 65%)
#   adding: content/lab21_lora_t4/r8/checkpoint-68/adapter_config.json (deflated 57%)
#   adding: content/lab21_lora_t4/r8/checkpoint-68/scaler.pt (deflated 64%)
#   adding: content/lab21_lora_t4/r8/checkpoint-68/optimizer.pt (deflated 10%)
#   adding: content/lab21_lora_t4/r8/checkpoint-68/training_args.bin (deflated 53%)
#   adding: content/lab21_lora_t4/r8/tokenizer.json (deflated 81%)
#   adding: content/lab21_lora_t4/r8/README.md (deflated 65%)
#   adding: content/lab21_lora_t4/r8/adapter_config.json (deflated 57%)
#   adding: content/lab21_lora_t4/r8/training_args.bin (deflated 53%)
#   adding: content/lab21_lora_t4/r64/ (stored 0%)
#   adding: content/lab21_lora_t4/r64/checkpoint-102/ (stored 0%)
#   adding: content/lab21_lora_t4/r64/checkpoint-102/trainer_state.json (deflated 71%)
#   adding: content/lab21_lora_t4/r64/checkpoint-102/rng_state.pth (deflated 27%)
#   adding: content/lab21_lora_t4/r64/checkpoint-102/adapter_model.safetensors (deflated 8%)
#   adding: content/lab21_lora_t4/r64/checkpoint-102/tokenizer_config.json (deflated 89%)
#   adding: content/lab21_lora_t4/r64/checkpoint-102/scheduler.pt (deflated 61%)
#   adding: content/lab21_lora_t4/r64/checkpoint-102/tokenizer.json (deflated 81%)
#   adding: content/lab21_lora_t4/r64/checkpoint-102/README.md (deflated 65%)
#   adding: content/lab21_lora_t4/r64/checkpoint-102/adapter_config.json (deflated 57%)
#   adding: content/lab21_lora_t4/r64/checkpoint-102/scaler.pt (deflated 64%)
#   adding: content/lab21_lora_t4/r64/checkpoint-102/optimizer.pt (deflated 13%)
#   adding: content/lab21_lora_t4/r64/checkpoint-102/training_args.bin (deflated 53%)
#   adding: content/lab21_lora_t4/r64/adapter_model.safetensors (deflated 8%)
#   adding: content/lab21_lora_t4/r64/tokenizer_config.json (deflated 89%)
#   adding: content/lab21_lora_t4/r64/checkpoint-34/ (stored 0%)
#   adding: content/lab21_lora_t4/r64/checkpoint-34/trainer_state.json (deflated 64%)
#   adding: content/lab21_lora_t4/r64/checkpoint-34/rng_state.pth (deflated 26%)
#   adding: content/lab21_lora_t4/r64/checkpoint-34/adapter_model.safetensors (deflated 8%)
#   adding: content/lab21_lora_t4/r64/checkpoint-34/tokenizer_config.json (deflated 89%)
#   adding: content/lab21_lora_t4/r64/checkpoint-34/scheduler.pt (deflated 61%)
#   adding: content/lab21_lora_t4/r64/checkpoint-34/tokenizer.json (deflated 81%)
#   adding: content/lab21_lora_t4/r64/checkpoint-34/README.md (deflated 65%)
#   adding: content/lab21_lora_t4/r64/checkpoint-34/adapter_config.json (deflated 57%)
#   adding: content/lab21_lora_t4/r64/checkpoint-34/scaler.pt (deflated 64%)
#   adding: content/lab21_lora_t4/r64/checkpoint-34/optimizer.pt (deflated 13%)
#   adding: content/lab21_lora_t4/r64/checkpoint-34/training_args.bin (deflated 53%)
#   adding: content/lab21_lora_t4/r64/checkpoint-68/ (stored 0%)
#   adding: content/lab21_lora_t4/r64/checkpoint-68/trainer_state.json (deflated 69%)
#   adding: content/lab21_lora_t4/r64/checkpoint-68/rng_state.pth (deflated 27%)
#   adding: content/lab21_lora_t4/r64/checkpoint-68/adapter_model.safetensors (deflated 8%)
#   adding: content/lab21_lora_t4/r64/checkpoint-68/tokenizer_config.json (deflated 89%)
#   adding: content/lab21_lora_t4/r64/checkpoint-68/scheduler.pt (deflated 61%)
#   adding: content/lab21_lora_t4/r64/checkpoint-68/tokenizer.json (deflated 81%)
#   adding: content/lab21_lora_t4/r64/checkpoint-68/README.md (deflated 65%)
#   adding: content/lab21_lora_t4/r64/checkpoint-68/adapter_config.json (deflated 57%)
#   adding: content/lab21_lora_t4/r64/checkpoint-68/scaler.pt (deflated 64%)
#   adding: content/lab21_lora_t4/r64/checkpoint-68/optimizer.pt (deflated 14%)
#   adding: content/lab21_lora_t4/r64/checkpoint-68/training_args.bin (deflated 53%)
#   adding: content/lab21_lora_t4/r64/tokenizer.json (deflated 81%)
#   adding: content/lab21_lora_t4/r64/README.md (deflated 65%)
#   adding: content/lab21_lora_t4/r64/adapter_config.json (deflated 57%)
#   adding: content/lab21_lora_t4/r64/training_args.bin (deflated 53%)
#   adding: content/lab21_lora_t4/qualitative_comparison.csv (deflated 62%)
#   adding: content/lab21_lora_t4/rank_experiment_summary.csv (deflated 37%)
#   adding: content/lab21_lora_t4/r16/ (stored 0%)
#   adding: content/lab21_lora_t4/r16/checkpoint-102/ (stored 0%)
#   adding: content/lab21_lora_t4/r16/checkpoint-102/trainer_state.json (deflated 71%)
#   adding: content/lab21_lora_t4/r16/checkpoint-102/rng_state.pth (deflated 27%)
#   adding: content/lab21_lora_t4/r16/checkpoint-102/adapter_model.safetensors (deflated 8%)
#   adding: content/lab21_lora_t4/r16/checkpoint-102/tokenizer_config.json (deflated 89%)
#   adding: content/lab21_lora_t4/r16/checkpoint-102/scheduler.pt (deflated 61%)
#   adding: content/lab21_lora_t4/r16/checkpoint-102/tokenizer.json (deflated 81%)
#   adding: content/lab21_lora_t4/r16/checkpoint-102/README.md (deflated 65%)
#   adding: content/lab21_lora_t4/r16/checkpoint-102/adapter_config.json (deflated 57%)
#   adding: content/lab21_lora_t4/r16/checkpoint-102/scaler.pt (deflated 64%)
#   adding: content/lab21_lora_t4/r16/checkpoint-102/optimizer.pt (deflated 11%)
#   adding: content/lab21_lora_t4/r16/checkpoint-102/training_args.bin (deflated 53%)
#   adding: content/lab21_lora_t4/r16/adapter_model.safetensors (deflated 8%)
#   adding: content/lab21_lora_t4/r16/tokenizer_config.json (deflated 89%)
#   adding: content/lab21_lora_t4/r16/checkpoint-34/ (stored 0%)
#   adding: content/lab21_lora_t4/r16/checkpoint-34/trainer_state.json (deflated 64%)
#   adding: content/lab21_lora_t4/r16/checkpoint-34/rng_state.pth (deflated 26%)
#   adding: content/lab21_lora_t4/r16/checkpoint-34/adapter_model.safetensors (deflated 8%)
#   adding: content/lab21_lora_t4/r16/checkpoint-34/tokenizer_config.json (deflated 89%)
#   adding: content/lab21_lora_t4/r16/checkpoint-34/scheduler.pt (deflated 61%)
#   adding: content/lab21_lora_t4/r16/checkpoint-34/tokenizer.json (deflated 81%)
#   adding: content/lab21_lora_t4/r16/checkpoint-34/README.md (deflated 65%)
#   adding: content/lab21_lora_t4/r16/checkpoint-34/adapter_config.json (deflated 57%)
#   adding: content/lab21_lora_t4/r16/checkpoint-34/scaler.pt (deflated 64%)
#   adding: content/lab21_lora_t4/r16/checkpoint-34/optimizer.pt (deflated 11%)
#   adding: content/lab21_lora_t4/r16/checkpoint-34/training_args.bin (deflated 53%)
#   adding: content/lab21_lora_t4/r16/checkpoint-68/ (stored 0%)
#   adding: content/lab21_lora_t4/r16/checkpoint-68/trainer_state.json (deflated 69%)
#   adding: content/lab21_lora_t4/r16/checkpoint-68/rng_state.pth (deflated 27%)
#   adding: content/lab21_lora_t4/r16/checkpoint-68/adapter_model.safetensors (deflated 8%)
#   adding: content/lab21_lora_t4/r16/checkpoint-68/tokenizer_config.json (deflated 89%)
#   adding: content/lab21_lora_t4/r16/checkpoint-68/scheduler.pt (deflated 61%)
#   adding: content/lab21_lora_t4/r16/checkpoint-68/tokenizer.json (deflated 81%)
#   adding: content/lab21_lora_t4/r16/checkpoint-68/README.md (deflated 65%)
#   adding: content/lab21_lora_t4/r16/checkpoint-68/adapter_config.json (deflated 57%)
#   adding: content/lab21_lora_t4/r16/checkpoint-68/scaler.pt (deflated 64%)
#   adding: content/lab21_lora_t4/r16/checkpoint-68/optimizer.pt (deflated 12%)
#   adding: content/lab21_lora_t4/r16/checkpoint-68/training_args.bin (deflated 53%)
#   adding: content/lab21_lora_t4/r16/tokenizer.json (deflated 81%)
#   adding: content/lab21_lora_t4/r16/README.md (deflated 65%)
#   adding: content/lab21_lora_t4/r16/adapter_config.json (deflated 57%)
#   adding: content/lab21_lora_t4/r16/training_args.bin (deflated 53%)
#
# ✓ Submission zip created successfully: lab21_lora_t4_submission.zip
# ✓ File size: 414.45 MB

# %%
from google.colab import files

if os.path.exists("lab21_lora_t4_submission.zip"):
    files.download("lab21_lora_t4_submission.zip")
else:
    print("Không tìm thấy file zip. Vui lòng kiểm tra lại bước nén file.")
